# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'D:\Shorya\python\EDA Practice csv\hotel_bookings.csv')
df.sample(4)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 113861  City Hotel            0         19               2017
# 84237   City Hotel            0         15               2016
# 71899   City Hotel            1         24               2017
# 52092   City Hotel            1        146               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 113861               June                        24
# 84237            February                         8
# 71899                July                        28
# 52092                 May                        23
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 113861                         11                        2
# 84237                          20                        0
# 71899                          15                        1
# 52092                          30                        1
#
#         stays_in_week_nights  adults  ...  deposit_type  agent company  \
# ...

# %% [markdown]
# # Review of the Bivariate Analysis
# Hotel Booking Cancellation Analysis — Comprehensive Bivariate Analysis Summary
# The bivariate analysis of the hotel booking dataset provided extensive insight into the behavioral, operational, demographic, and pricing-related factors influencing reservation cancellations across City Hotel and Resort Hotels. Building upon the findings from the univariate analysis, the study revealed that cancellation behavior is primarily driven by booking intent, customer engagement, distribution strategy, pricing dynamics, and operational characteristics rather than purely demographic attributes.
#
# The earlier univariate analysis established several foundational patterns within the dataset. The booking ecosystem was heavily dominated by City Hotels, OTA-driven reservations, transient customers, short-duration stays, and highly skewed lead times. Features such as ADR, booking changes, waiting-list duration, special requests, agent IDs, and distribution channels displayed strong variability and non-uniform distributions, indicating diverse booking behaviors and customer segments. The dataset also demonstrated clear operational complexity through dynamic pricing, room reallocations, intermediary dependence, and seasonal demand concentration.
#
# The bivariate analysis significantly expanded these findings by identifying direct relationships between individual features and cancellation outcomes. Behavioral and transactional variables consistently emerged as the strongest cancellation indicators. Long lead times showed substantially higher cancellation probability, confirming that customers booking far in advance are more likely to modify or abandon travel plans. Deposit policies exhibited extremely strong predictive power, with non-refundable bookings strongly associated with cancellation-heavy segments, reflecting hotel-side risk management strategies and booking conditions.
#
# Customer engagement indicators such as booking changes, special requests, and parking requirements demonstrated remarkably stabilizing effects on reservations. Customers actively interacting with their bookings — by modifying reservations, requesting parking spaces, or adding multiple special requests — were significantly less likely to cancel, indicating stronger travel commitment and booking intent.
#
# The analysis of customer demographics and occupancy-related features revealed comparatively weaker relationships with cancellation behavior. Variables such as adults, children, babies, stays_in_week_nights, and stays_in_weekend_nights displayed only modest and inconsistent predictive relationships compared to behavioral and operational features. The dataset was dominated by couple-based travel patterns involving two adults, while family-oriented bookings with children or babies represented a smaller share of reservations. Although family bookings occasionally appeared slightly more stable, especially in Resort Hotels, demographic composition alone did not strongly influence cancellation probability. Similarly, stay-duration variables reflected dominant short-stay travel behavior but showed limited standalone predictive importance.
#
# Distribution-channel analysis revealed that OTA and intermediary-driven reservations contributed disproportionately to cancellations, while repeat guests and corporate/company bookings demonstrated significantly greater stability and reliability. Customer segmentation analysis further reinforced these findings: transient customers consistently exhibited the highest cancellation risk, whereas group travelers, contract bookings, and company-based reservations displayed more predictable booking behavior.
#
# Pricing analysis through ADR revealed that higher-priced reservations, particularly in Resort Hotels, were more vulnerable to cancellation. This pattern reflected the uncertainty associated with premium leisure travel, seasonal demand fluctuations, and dynamic pricing strategies. Meal-plan analysis also suggested that fully packaged bookings such as Full Board reservations exhibited elevated cancellation tendencies compared to more flexible meal arrangements.
#
# The analysis additionally highlighted strong structural differences between hotel types. City Hotels consistently experienced higher cancellation rates across most features, suggesting greater exposure to flexible urban travel behavior, business uncertainty, and OTA-driven volatility. Resort Hotels generally displayed more stable booking patterns but showed stronger sensitivity to pricing-related features such as ADR, meal plans, and seasonal demand.
#
# Key Behavioral Patterns Detected
# Several highly significant behavioral and operational patterns emerged consistently throughout the analysis:
#
# Customers exhibiting higher engagement levels — through booking modifications, parking requests, and multiple special requests — were significantly less likely to cancel.
# Reservations with zero interaction indicators consistently displayed the highest cancellation risk.
# Long advance bookings were substantially more volatile than short-term reservations.
# OTA and intermediary-driven bookings generated considerably higher cancellation exposure compared to direct, corporate, or repeat-customer reservations.
# Repeat guests demonstrated exceptionally strong booking reliability, indicating clear customer loyalty effects.
# City Hotel bookings consistently showed greater cancellation volatility than Resort Hotel reservations across nearly all major features.
# Group and company-based bookings behaved far more predictably than transient independent travelers.
# High-value resort reservations exhibited stronger pricing sensitivity and higher cancellation probability.
# Demographic variables such as adults, children, babies, and stay durations showed relatively weak predictive relationships compared to behavioral and operational features.
# Customers making multiple special requests or requiring parking spaces demonstrated exceptionally strong booking commitment.
# Major Trends Observed During Analysis
# The analysis revealed several important operational and market-level trends:
#
# 1. Strong OTA Dependence
# The dataset showed heavy reliance on Online Travel Agencies and travel intermediaries, making cancellation behavior highly sensitive to third-party booking ecosystems.
#
# 2. Dynamic Pricing Environment
# ADR distributions demonstrated strong evidence of dynamic pricing strategies influenced by seasonality, room categories, customer segments, and demand fluctuations.
#
# 3. Seasonal Demand Concentration
# Booking activity peaked during high-tourism periods, particularly in summer months, with Resort Hotels exhibiting stronger leisure-season demand patterns.
#
# 4. Low Customer Retention
# Repeat guests represented only a small fraction of total reservations, suggesting a predominantly tourism-driven and short-term customer base.
#
# 5. Operational Reallocation Behavior
# Assigned room types frequently differed from reserved room types, indicating active inventory optimization and operational flexibility.
#
# 6. Behavioral Signals Strongly Outperform Demographics
# Behavioral, transactional, and operational features consistently outperformed demographic variables in predictive relevance for cancellation behavior.
#
# 7. Strong Urban vs Leisure Travel Divide
# City Hotels exhibited highly flexible and cancellation-prone booking behavior, while Resort Hotels reflected comparatively stable but price-sensitive leisure travel patterns.
#
# Most Important Features for Building a Classification Model
# The following features emerged as the strongest predictors for hotel booking cancellation classification:
#
# #### Feature	Significance
#
# **lead_time	Strongest behavioral predictor; long advance bookings showed significantly higher cancellation risk
# deposit_type	Extremely high predictive power reflecting customer commitment and hotel risk policies
# market_segment	Captures booking intent and customer acquisition channel behavior
# distribution_channel	OTA and TA/TO channels strongly associated with cancellation-heavy reservations
# total_of_special_requests	Strong inverse relationship with cancellation; engaged customers rarely cancel
# required_car_parking_spaces	Highly stable bookings associated with parking requirements
# repeated_guest	Strong loyalty signal; repeat customers rarely cancel
# previous_cancellations	Direct indicator of habitual cancellation behavior
# previous_bookings_not_canceled	Strong customer reliability and trustworthiness signal
# customer_type	Transient customers showed substantially higher cancellation probability
# adr	Important pricing and revenue-based cancellation indicator
# booking_changes	Reservation modifications strongly associated with booking commitment
# agent	Major intermediary behavior differences contribute to cancellation variability
# company	Corporate bookings generally more stable and reliable
# meal_full	Captures travel style and booking-package characteristics
# reserved_room_type & assigned_room_type	Reflect operational allocation behavior and booking expectations**
#
# ### Features Recommended for Removal
#
# Certain features should be excluded from predictive modeling due to leakage, redundancy, or operational irrelevance:
#
# **Feature	Reason for Removal
# reservation_status	Direct target leakage; fully determined by booking outcome
# reservation_status_date	Severe target leakage; reflects post-outcome operational status timing
# Raw agent IDs (optional)	High cardinality; may require encoding/grouping before use
# Raw company IDs (optional)	High cardinality with sparse categories
# Extremely sparse categories	Low-frequency values may introduce noise and overfitting
# Recommended Feature Engineering Strategies**
#
# ### Several strong feature-engineering opportunities emerged during the analysis:**
#
# Behavioral Features
# Create engagement scores using:
#
# **special requests,
# booking changes,
# parking requirements,
# repeat-guest behavior.
# Time-Based Features**
#
# Extract:
#
# **booking season,
# arrival quarter,
# peak/off-season indicators,
# weekday/weekend stay ratios.
# Lead Time Transformations**
#
# Bin lead times into:
#
# short,
# medium,
# long-term booking groups.
#
# ADR Engineering
#
# Create:
#
# **ADR bins,
# hotel-wise normalized ADR,
# seasonal pricing indicators.
# High-Cardinality Encoding**
#
# For agent, company, and country:
#
# **frequency encoding,
# target encoding,
# grouping rare categories,
# top-category consolidation.
# Room Allocation Features**
#
# Create room mismatch indicators:
#
# **reserved vs assigned room differences,
# upgrade/downgrade flags.
# Customer Reliability Scores**
# Combine:
#
# **previous cancellations,
# previous successful bookings,
# repeat guest behavior,
# booking modifications.
# Family & Occupancy Features**
# Create:
#
# **total guests feature (adults + children + babies),
# family vs non-family booking indicators,
# occupancy-density metrics.**
# Final Conclusion
# The hotel booking cancellation analysis revealed that reservation cancellations are fundamentally driven by customer behavior, booking intent, distribution-channel dynamics, operational strategies, and pricing conditions rather than simple demographic characteristics. Features capturing engagement, commitment, loyalty, booking flexibility, and intermediary behavior consistently outperformed static customer attributes in predictive importance. The dataset demonstrated strong evidence of OTA-driven volatility, dynamic pricing behavior, seasonal demand effects, operational complexity, and distinct travel patterns between urban and leisure hotel environments.
#
# From a machine learning perspective, the dataset is exceptionally well-suited for classification modeling due to the presence of numerous high-signal behavioral features, clear cancellation patterns, and meaningful interactions between customer behavior and hotel operations. With appropriate preprocessing, leakage removal, feature engineering, encoding strategies, and imbalance handling, the dataset has strong potential for building highly accurate hotel cancellation prediction systems capable of supporting revenue optimization, operational planning, customer segmentation, customer-retention strategies, and proactive risk-management decision-making.

# %%
num_cols = [
    'lead_time',
    'adr',
    'adults',
    'children',
    'babies',
    'stays_in_weekend_nights',
    'stays_in_week_nights',
    'booking_changes',
    'days_in_waiting_list',
    'previous_cancellations',
    'previous_bookings_not_canceled'
]

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## insights
#
# The provided image is a **Correlation Heatmap** analyzing 11 different numerical variables, likely originating from a hotel or hospitality booking dataset.
#
# Overall, the variables show **very weak to moderate linear relationships**. There are no extremely strong correlations ($r > 0.7$), suggesting a low risk of multi-collinearity among these specific features if used in a predictive model.
#
# ---
#
# ## Key Observations
#
# ### 1. Notable Positive Correlations
#
# * **`stays_in_week_nights` and `stays_in_weekend_nights` (0.5):** This is the strongest correlation in the dataset. It indicates a moderate positive relationship, showing that guests who book longer weekday stays also tend to book weekend stays (i.e., longer overall trips).
# * **`adr` (Average Daily Rate) and `children` (0.32) / `adults` (0.23):** Higher room rates are moderately associated with bookings that include children and adults. This aligns with standard hotel pricing, where larger groups or family rooms cost more.
# * **`lead_time` and `stays_in_week_nights` (0.17) / `days_in_waiting_list` (0.17):** Guests booking longer stays tend to plan further in advance. Similarly, bookings that end up waiting longer on a list generally have longer lead times.
# * **`previous_cancellations` and `previous_bookings_not_canceled` (0.15):** There is a slight positive correlation, meaning guests who frequently book at this establishment tend to have a history of both completed stays and cancellations.
#
# ### 2. Notable Negative Correlations
#
# * **`adults` and `previous_bookings_not_canceled` (-0.11):** A very slight negative correlation, suggesting that repeat visitors are slightly more likely to book single-adult rooms (potentially business travelers).
# * **`lead_time` and `previous_bookings_not_canceled` (-0.074) / `adr` (-0.063):** Repeat customers tend to book closer to their arrival date (shorter lead time) and may secure slightly lower average daily rates.
#
# ---
#
# ## Conclusion
#
# Most variables hover near $0.0$, indicating that they vary independently of one another. The most meaningful predictors of room pricing (`adr`) appear to be the number of guests (especially children), while the overall length of stay is naturally split across weekdays and weekends.

# %% [markdown]
# ## Lead Time + Deposit Type

# %%
pd.crosstab(
    [df['deposit_type'], pd.qcut(df['lead_time'], 4)],
    df['is_canceled'],
    normalize='index'
) * 100
# Out:
# is_canceled                          0           1
# deposit_type lead_time
# No Deposit   (-0.001, 18.0]  86.092649   13.907351
#              (18.0, 69.0]    68.371792   31.628208
#              (69.0, 160.0]   66.071775   33.928225
#              (160.0, 737.0]  62.172515   37.827485
# Non Refund   (-0.001, 18.0]   9.059233   90.940767
#              (18.0, 69.0]     0.594273   99.405727
#              (69.0, 160.0]    0.179949   99.820051
#              (160.0, 737.0]   0.572497   99.427503
# Refundable   (-0.001, 18.0]  87.500000   12.500000
#              (18.0, 69.0]    55.555556   44.444444
#              (69.0, 160.0]    0.000000  100.000000
#              (160.0, 737.0]  79.487179   20.512821

# %%
pivot_table = pd.crosstab(
    [df['deposit_type'], pd.qcut(df['lead_time'], 4)],
    df['is_canceled'],
    normalize='index'
) * 100

cancel_rates = pivot_table[1].unstack()

plt.figure(figsize=(10,6))

sns.heatmap(
    cancel_rates,
    annot=True,
    fmt='.1f',
    cmap='Reds'
)

plt.title('Cancellation Rate by Deposit Type and Lead Time')
plt.ylabel('Deposit Type')
plt.xlabel('Lead Time Quartile')

plt.show()

# %% [markdown]
# Key Findings
# 1. No Deposit Bookings
#
# Bookings without any deposit show a clear increase in cancellation probability as lead time increases.
#
# Short lead-time bookings (0–18 days) have relatively low cancellation rates (~13.9%)
# Cancellation rates steadily rise for medium and long lead-time bookings
# Very long advance bookings (160+ days) reach nearly 38% cancellation
# Insight
#
# Customers making flexible bookings far in advance are significantly more likely to cancel later. This confirms that:
#
# lead_time is a major cancellation driver
# flexible booking policies increase booking uncertainty
#
# 2. Non-Refundable Bookings
#
# Non-refundable bookings exhibit extremely high cancellation rates across all lead-time categories.
#
# Cancellation rates remain above 90% in every segment
# Medium and long lead-time bookings approach nearly 100% cancellation
# Insight
#
# This indicates that the deposit_type feature has exceptionally strong predictive power in the dataset. The pattern may reflect operational booking behavior or reservation management practices rather than normal customer behavior.
#
# This interaction becomes one of the strongest indicators of cancellation risk.
#
# 3. Refundable Bookings
#
# Refundable bookings show inconsistent cancellation behavior.
#
# Short lead-time bookings remain relatively stable
# Mid-range lead times show increased cancellations
# One segment reaches 100% cancellation
# Insight
#
# The instability likely results from very small sample sizes in the Refundable category, making these percentages less reliable for general conclusions.
#
# Overall Conclusion
#
# The interaction between:
#
# deposit_type
# lead_time
#
# reveals a powerful behavioral pattern in hotel reservation cancellations.
#
# The analysis shows that:
#
# long advance bookings are inherently riskier
# financial commitment strongly affects booking reliability
# cancellation behavior is primarily behavioral rather than demographic
#
# This combination can serve as a highly valuable feature for predictive modeling and customer risk segmentation.

# %% [markdown]
# ## Market Segment + Lead Time

# %%
plt.figure(figsize=(12,6))

sns.boxplot(
    x='market_segment',
    y='lead_time',
    hue='is_canceled',
    data=df
)

plt.xticks(rotation=45)

plt.show()

# %%
market_lead_summary = df.groupby(
    ['market_segment', 'is_canceled']
)['lead_time'].describe()

market_lead_summary
# Out:
#                               count        mean         std  min    25%  \
# market_segment is_canceled
# Aviation       0              185.0    4.140541    4.052875  0.0   1.00
#                1               52.0    5.519231    6.121292  0.0   1.00
# Complementary  0              646.0   12.623839   31.996502  0.0   0.00
#                1               97.0   17.701031   30.378229  0.0   0.00
# Corporate      0             4303.0   16.861027   32.001950  0.0   1.00
#                1              992.0   44.961694   48.969549  0.0   8.00
# Direct         0            10672.0   45.956990   67.309755  0.0   1.00
#                1             1934.0   71.391417   80.678655  0.0  10.00
# Groups         0             7714.0  139.060669  119.487257  0.0  40.00
#                1            12097.0  217.525833  138.420316  0.0  97.00
# Offline TA/TO  0            15908.0  118.516910  107.453200  0.0  32.00
#                1             8311.0  166.563109  113.761355  0.0  71.00
# ...

# %% [markdown]
# The multivariate analysis of `market_segment`, `lead_time`, and `is_canceled` reveals strong behavioral differences across booking channels and clearly shows that canceled bookings generally have significantly higher lead times than successful bookings. The `Groups` segment exhibits the highest booking horizons, with canceled group reservations having an average lead time of approximately 218 days compared to 139 days for non-canceled bookings, indicating that large advance group reservations are highly cancellation-prone. Similarly, `Offline TA/TO` and `Online TA` segments show substantial increases in lead time among canceled bookings, confirming that intermediary-based reservations made far in advance are operationally volatile and highly susceptible to changes. The `Direct` segment also demonstrates a noticeable increase in cancellation-related lead time, although with lower overall booking horizons compared to group bookings. In contrast, `Corporate` and `Aviation` bookings display relatively lower lead times and tighter distributions, suggesting more stable and predictable travel behavior. The analysis also reveals the presence of extreme outliers across several segments, particularly in `Groups`, `Direct`, and `Offline TA/TO`, indicating long-term planning behavior and seasonal or bulk reservation effects. Overall, the results strongly reinforce one of the central findings of the EDA: longer booking lead times are consistently associated with higher cancellation probability, especially within OTA and group-based booking channels.

# %% [markdown]
# ## ADR + Cancellation + Hotel Type

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    x='hotel',
    y='adr',
    hue='is_canceled',
    data=df
)

plt.show()

# %%
adr_summary = df.groupby(
    ['hotel', 'is_canceled']
)['adr'].agg([
    'count',
    'mean',
    'median',
    'std',
    'min',
    'max'
]).round(2)

adr_summary
# Out:
#                           count    mean  median    std   min     max
# hotel        is_canceled
# City Hotel   0            46228  105.75    99.9  40.60  0.00   510.0
#              1            33102  104.69    99.8  47.48  0.00  5400.0
# Resort Hotel 0            28938   90.79    72.0  59.32 -6.38   508.0
#              1            11122  105.79    84.0  65.42  0.00   450.0

# %% [markdown]
# The multivariate analysis of `hotel`, `adr` (Average Daily Rate), and `is_canceled` reveals clear pricing and cancellation behavior differences between City Hotels and Resort Hotels. In both hotel types, canceled bookings generally exhibit higher ADR values compared to non-canceled bookings, indicating that expensive reservations are more prone to cancellation. This pattern is particularly noticeable in City Hotels, where pricing variability is significantly higher and ADR distributions are more spread out, reflecting aggressive dynamic pricing behavior and stronger demand fluctuations. Resort Hotels, while also showing higher ADRs among canceled bookings, display relatively more stable pricing distributions compared to City Hotels. The boxplot further highlights the presence of numerous high-value ADR outliers in canceled bookings, suggesting that premium-priced reservations are operationally riskier and more volatile. Overall, the analysis indicates that pricing plays an important role in customer cancellation behavior, with higher-priced bookings carrying greater uncertainty and cancellation exposure, especially in City Hotel segments.

# %% [markdown]
# ## Repeated Guest + Previous Cancellations

# %%
pd.crosstab(
    [df['is_repeated_guest'], df['previous_cancellations']],
    df['is_canceled'],
    normalize='index'
) * 100
# Out:
# is_canceled                                       0           1
# is_repeated_guest previous_cancellations
# 0                 0                       65.287258   34.712742
#                   1                        1.082493   98.917507
#                   2                       45.000000   55.000000
#                   3                        7.692308   92.307692
#                   6                        0.000000  100.000000
#                   11                       0.000000  100.000000
#                   14                       0.000000  100.000000
#                   19                       0.000000  100.000000
#                   24                       0.000000  100.000000
#                   25                       0.000000  100.000000
#                   26                       0.000000  100.000000
# 1                 0                       96.878252    3.121748
#                   1                       40.259740   59.740260
# ...

# %%
repeat_cancel = pd.crosstab(
    [df['is_repeated_guest'], df['previous_cancellations']],
    df['is_canceled'],
    normalize='index'
) * 100

cancel_rates = repeat_cancel[1].unstack()

plt.figure(figsize=(12,6))

sns.heatmap(
    cancel_rates,
    annot=True,
    fmt='.1f',
    cmap='Reds'
)

plt.title('Cancellation Rate by Repeat Guest Status and Previous Cancellations')
plt.xlabel('Previous Cancellations')
plt.ylabel('Repeated Guest')

plt.show()

# %% [markdown]
# Key Findings
# 1. Non-Repeated Guests with Previous Cancellations Are Extremely High-Risk Customers
#
# Among customers who are not repeated guests (is_repeated_guest = 0), cancellation probability rises dramatically as the number of previous cancellations increases.
#
# Customers with no previous cancellations show a cancellation rate of ~34.7%
# Customers with one previous cancellation show an extremely high cancellation rate of ~98.9%
# Several higher previous cancellation counts reach nearly or exactly 100% cancellation
# Interpretation
#
# This indicates the presence of:
#
# habitual cancellers
# unreliable booking behavior
# high-risk transient customers
#
# Historical cancellation behavior becomes one of the strongest predictors of future cancellations.
#
# 2. Repeated Guests Are Significantly More Reliable
#
# Repeated guests (is_repeated_guest = 1) display very low cancellation rates when they have no prior cancellation history.
#
# Repeat guests with zero previous cancellations show only ~3.1% cancellation
# This is dramatically lower than non-repeated guests
# Interpretation
#
# This confirms strong customer loyalty effects:
#
# repeat customers are operationally stable
# they exhibit significantly higher booking commitment
# they are much less likely to cancel reservations
# 3. Previous Cancellation History Still Matters for Repeat Guests
#
# Even among repeated guests, customers with prior cancellation history show elevated cancellation risk.
#
# For example:
#
# repeated guests with one previous cancellation show ~59.7% cancellation
# some extreme historical cancellation cases again approach very high cancellation probabilities
# Interpretation
#
# While loyalty reduces risk overall, prior cancellation behavior remains a highly influential behavioral signal even for returning customers.
#
# 4. Extreme Values Likely Reflect Small Sample Sizes
#
# Several combinations with:
#
# very high previous cancellation counts
# 100% cancellation rates
#
# likely contain very small numbers of observations.
#
# Interpretation
#
# These should be interpreted cautiously because:
#
# percentages become unstable at low counts
# rare customer profiles can exaggerate patterns
#
# However, the overall behavioral trend remains very strong and consistent.
#
# Overall Conclusion
#
# The interaction between:
#
# is_repeated_guest
# previous_cancellations
# is_canceled
#
# reveals one of the clearest behavioral segmentation patterns in the dataset.
#
# The analysis strongly confirms that:
#
# repeat customers are far more reliable
# historical cancellation behavior is a major predictor of future cancellations
# habitual cancellation patterns exist within certain customer groups
#
# This makes customer history features extremely valuable for predictive modeling and customer risk profiling.

# %% [markdown]
# # Time-Based Multivariate Analysis

# %% [markdown]
# ## Seasonal Pricing + Cancellation

# %%
# Arrange months in proper chronological order

month_order = [
    'January', 'February', 'March', 'April',
    'May', 'June', 'July', 'August',
    'September', 'October', 'November', 'December'
]

monthly_adr = df.groupby(
    ['arrival_date_month', 'hotel']
)['adr'].mean().reset_index()

monthly_adr['arrival_date_month'] = pd.Categorical(
    monthly_adr['arrival_date_month'],
    categories=month_order,
    ordered=True
)

monthly_adr = monthly_adr.sort_values('arrival_date_month')

plt.figure(figsize=(14,6))

sns.lineplot(
    x='arrival_date_month',
    y='adr',
    hue='hotel',
    data=monthly_adr,
    marker='o'
)

plt.xticks(rotation=45)

plt.title('Average ADR by Month and Hotel Type')
plt.xlabel('Month')
plt.ylabel('Average Daily Rate (ADR)')

plt.show()

# %%
monthly_cancel = df.groupby(
    ['arrival_date_month', 'hotel']
)['is_canceled'].mean().reset_index()

monthly_cancel['is_canceled'] = (
    monthly_cancel['is_canceled'] * 100
).round(2)

monthly_cancel
# Out:
#    arrival_date_month         hotel  is_canceled
# 0               April    City Hotel        46.32
# 1               April  Resort Hotel        29.34
# 2              August    City Hotel        40.10
# 3              August  Resort Hotel        33.45
# 4            December    City Hotel        42.11
# 5            December  Resort Hotel        23.83
# 6            February    City Hotel        38.29
# 7            February  Resort Hotel        25.62
# 8             January    City Hotel        39.67
# 9             January  Resort Hotel        14.82
# 10               July    City Hotel        40.88
# 11               July  Resort Hotel        31.40
# 12               June    City Hotel        44.69
# 13               June  Resort Hotel        33.07
# 14              March    City Hotel        36.95
# 15              March  Resort Hotel        22.87
# 16                May    City Hotel        44.38
# 17                May  Resort Hotel        28.77
# ...

# %% [markdown]
# The monthly cancellation analysis reveals clear seasonal and hotel-type-based differences in booking behavior across the year. City Hotels consistently exhibit significantly higher cancellation rates than Resort Hotels in every month, indicating that urban hotel bookings are operationally more volatile and sensitive to customer plan changes. Cancellation rates for City Hotels remain persistently high throughout the year, generally ranging between 37% and 46%, with the highest cancellations observed during April, June, May, October, and September. This suggests strong exposure to dynamic business travel, short-term planning changes, and OTA-driven booking behavior. In contrast, Resort Hotels demonstrate comparatively lower and more stable cancellation rates, typically ranging between 15% and 33%, reflecting more committed leisure-oriented travel behavior. Resort Hotel cancellations increase noticeably during peak tourism periods such as June, July, August, and September, likely due to seasonal vacation demand and advance holiday bookings. January and November show the lowest cancellation rates for Resort Hotels, indicating relatively stable off-season demand. Overall, the analysis confirms strong seasonality effects in hotel booking cancellations and highlights that City Hotels experience consistently greater cancellation volatility compared to Resort Hotels across all months of the year.

# %% [markdown]
# # Multivariate Analysis Summary
#
# The multivariate analysis of the hotel booking dataset provided a deeper understanding of how multiple features interact simultaneously to influence booking cancellations, customer behavior, pricing dynamics, and operational patterns. Unlike univariate and bivariate analysis, this phase focused on identifying combined behavioral relationships and uncovering hidden patterns across customer segments, booking channels, hotel types, seasonal trends, and financial commitment structures.
#
# The analysis revealed that booking cancellations are largely driven by behavioral and operational variables rather than demographic characteristics. Features such as `lead_time`, `deposit_type`, `market_segment`, `distribution_channel`, customer booking history, and pricing variables demonstrated strong interaction effects with cancellation behavior. Long advance bookings consistently showed significantly higher cancellation probabilities, particularly when combined with flexible booking policies such as “No Deposit” reservations. In contrast, repeat customers and customers with no previous cancellation history exhibited substantially lower cancellation rates, highlighting the importance of customer loyalty and historical booking reliability.
#
# The interaction analysis between `market_segment`, `lead_time`, and `is_canceled` further demonstrated that OTA-driven and group-based reservations are operationally more volatile and highly prone to cancellations, especially when booked far in advance. Corporate and direct bookings, on the other hand, displayed comparatively stable booking behavior with shorter booking horizons and lower cancellation tendencies.
#
# Seasonality analysis revealed strong temporal effects in hotel operations. City Hotels consistently experienced higher cancellation rates than Resort Hotels across all months, indicating greater exposure to dynamic travel behavior and short-term booking modifications. Resort Hotels exhibited more stable booking patterns, although cancellation rates increased during peak tourism seasons due to advance vacation planning and leisure travel demand. Pricing analysis using ADR (`Average Daily Rate`) highlighted that higher-priced bookings tend to carry greater cancellation risk, especially in City Hotels where pricing variability and demand fluctuations were significantly higher.
#
# The multivariate analysis also identified the presence of habitual cancellation behavior among certain customer groups. Customers with previous cancellation history showed extremely high probabilities of future cancellations, even among repeated guests, making historical booking behavior one of the strongest predictors in the dataset. Overall, the analysis confirmed that hotel booking cancellations are strongly influenced by a combination of customer commitment level, booking timing, distribution channel behavior, pricing dynamics, and customer history rather than purely demographic factors.
#
# ---
#
# # Major Insights Generated from the Dataset
#
# ## Booking & Cancellation Behavior
#
# * Longer `lead_time` is consistently associated with higher cancellation probability.
# * Flexible booking policies (`No Deposit`) significantly increase cancellation risk.
# * Customers with previous cancellation history exhibit extremely high future cancellation probabilities.
# * Repeat guests are substantially more reliable and operationally stable than new customers.
# * Booking behavior is driven more by customer intent and flexibility than by guest demographics.
#
# ---
#
# ## Market Segment & Distribution Insights
#
# * `Online TA`, `Offline TA/TO`, and `Groups` segments are the most cancellation-prone customer groups.
# * Group bookings have the highest booking horizons and operational volatility.
# * Corporate and direct bookings display comparatively stable booking patterns.
# * OTA dependency is a major contributor to booking instability and cancellation exposure.
#
# ---
#
# ## Seasonal & Hotel-Type Insights
#
# * City Hotels consistently experience higher cancellation rates than Resort Hotels.
# * Peak tourism seasons show increased pricing and cancellation volatility.
# * Resort Hotels demonstrate more stable customer commitment, especially during off-season periods.
# * Seasonal demand strongly influences ADR and reservation behavior.
#
# ---
#
# ## Pricing & Revenue Insights
#
# * Higher ADR bookings are more likely to be canceled.
# * City Hotels exhibit stronger dynamic pricing behavior and ADR variability.
# * Premium-priced reservations carry greater operational uncertainty.
# * ADR serves as an important indicator of customer booking behavior and revenue patterns.
#
# ---
#
# ## Customer Loyalty & Behavioral Insights
#
# * Repeat customers are significantly less likely to cancel bookings.
# * Historical booking behavior is one of the strongest indicators of customer reliability.
# * Habitual cancellation patterns exist within specific customer groups.
# * Customer loyalty contributes strongly to operational stability.
#
# ---
#
# # Most Significant Features in the Dataset
#
# ## Highly Significant Predictive Features
#
# * `lead_time`
# * `deposit_type`
# * `market_segment`
# * `distribution_channel`
# * `previous_cancellations`
# * `previous_bookings_not_canceled`
# * `is_repeated_guest`
# * `adr`
# * `hotel`
# * `reserved_room_type`
# * `assigned_room_type`
# * `booking_changes`
# * `customer_type`
#
# ---
#
# ## Moderately Significant Features
#
# * `country`
# * `agent`
# * `company`
# * `total_of_special_requests`
# * `arrival_date_month`
# * `stays_in_week_nights`
# * `stays_in_weekend_nights`
#
# ---
#
# ## Relatively Weak Features
#
# * `adults`
# * `children`
# * `babies`
# * `arrival_date_day_of_month`
# * `arrival_date_week_number`
#
# These demographic and calendar-based features showed comparatively weaker direct relationships with cancellation behavior but may still contribute useful interaction effects during machine learning modeling.
#
# ---
#
# # Overall Conclusion
#
# The multivariate analysis established that hotel booking cancellations are primarily behavioral, operational, and policy-driven phenomena. Features related to booking commitment, historical customer behavior, reservation timing, pricing strategy, and booking channels emerged as the strongest drivers of cancellation outcomes. The analysis also highlighted the importance of customer segmentation, seasonality, and operational booking policies in understanding hotel demand dynamics. These insights provide a strong foundation for feature engineering, predictive modeling, customer risk profiling, and revenue optimization in the next stages of the project.
